# %% [markdown]
# <br>
# <p style="text-align: center;"><font size=6><b>EAE1106 - Métodos Computacionais para Economistas</b></font></p>
#
# <p style="text-align: center;"> Departamento de Economia | Faculdade de Economia, Administração, Contabilidade e Atuaria <br> Universidade de São Paulo <br><br></p>
#
# <p style="text-align: center;"><font size=4>Prof. Danilo Souza</font> <br>
#     <a href="https://www.danilosouza.com/">danilosouza.com</a>
#     <br><br>
# </p>
#
# <hr>

# %% [markdown]
# <font size=6><b>1ª Lista de Exercícios </b></font>
#
# <br>
# 1. Escreva um programa que conta quantos números entre 1 e 200 são divisíveis por 7 e imprima o resultado.

# %%
#Resposta:

# %% [markdown]
# ---

# %% [markdown]
# 2. Escreva um programa que receba do usuário um número inteiro positivo e calcule a soma dos dígitos desse número (exemplo: 1234 retorna 10). Em seguida, imprima o resultado.
# Dica: lembre-se que você pode iterar sobre strings em Python.

# %%
#Resposta:

# %% [markdown]
# ---

# %% [markdown]
# 3. Veja o dicionário que contém uma lista telefônica. Cada chave do dicionário é o nome de uma pessoa e o valor deve ser o telefone dessa pessoa. Escreva um programa que receba do usuário o nome de alguém e, em seguida, imprima o telefone dessa pessoa. Se a pessoa não estiver na lista, informe isso. Faça que o programa aceite tanto letras maiúsculas quanto minúsculas (Ex: aceita tanto "danilo" quanto "Danilo").

# %%
lista_telefonica = {
    'Danilo': 1199134234,
    'Tom': 1999564752,
    'Solange': 1191234876,
    'Fabiana': 1193546689,
}

# %%
#Resposta:

# %% [markdown]
# 4. Escreva um programa que receba uma palavra do usuário e verifique se ela é um anagrama de outra palavra fornecida. Um anagrama é uma palavra formada pelas mesmas letras de outra, em ordem diferente (ex: "amor" e "Roma").

# %%
#Resposta:

# %% [markdown]
# ---

# %% [markdown]
# Vamos fazer um exercício com listas que contém informações sobre um time da NBA.
#
# Suponha que você possua quatro listas, contendo o número de pontos feitos, sofridos, o adversário que o time *Houston Rockets* jogou, bem como o mando de campo nos seus últimos 10 jogos da NBA.
#
# A partir desses dados, responda as questões de 5 a 9.

# %%
pontos_feitos = [106, 120, 113, 93, 107, 92, 116, 117, 123, 124]
pontos_sofridos = [99, 145, 99, 129, 105, 100, 124, 95, 122, 132]
adversario = ["Trailblazers", "Spurs", "Raptors", "Nuggets", "Pelicans", "Lakers", "Lakers", "Hawks", "Heat", "Bulls"]
mando = ["Away", "Home", "Away", "Home", "Away", "Away", "Away", "Away", "Away", "Home"]

# %% [markdown]
# 5. Calcule o diferencial de pontos por jogo (sob o ponto de vista do Houston, isto é, alguns jogos devem ter diferencial positivo e outros negativo). Use um loop for.

# %%
#Resposta:

# %% [markdown]
# ---

# %% [markdown]
# 6. Qual é a média do diferencial de pontos? Arrendonde para duas casas decimais com round()

# %%
#Resposta:

# %% [markdown]
# ---

# %% [markdown]
# 7. Calcule os jogos em que Houston ganhou ou perdeu por 10 pontos ou menos de diferença e faça uma lista em que constam os adversários desses jogos.

# %%
#Resposta:

# %% [markdown]
# ---

# %% [markdown]
# 8. Calcule a média de pontos feitos por Houston em casa. Arredonde para duas casas decimais com round().

# %%
#Resposta:

# %% [markdown]
# ---

# %% [markdown]
# 9. Calcule o percentual de vitórias de Houston. Deixe a resposta em percentual em valor inteiro (ex: 25%).

# %%
#Resposta:
